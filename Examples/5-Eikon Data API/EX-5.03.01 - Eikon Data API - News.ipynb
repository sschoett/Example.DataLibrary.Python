# %% [markdown]
# ----
# <img src="../../files/refinitiv.png" width="20%" style="vertical-align: top;">
#
# # Data Library for Python
#
# ----

# %% [markdown]
# ## Eikon Data API - News examples
# This notebook demonstrates how to retrieve News Headlines and News Stories from Eikon or Refinitiv Workspace.
#
# #### Learn more
# To learn more about the Data API just connect to the Refinitiv Developer Community. By [registering](https://developers.refinitiv.com/iam/register) and [login](https://developers.refinitiv.com/iam/login) to the Refinitiv Developer Community portal you will get free access to a number of learning materials like [Quick Start guides](https://developers.refinitiv.com/eikon-apis/eikon-data-api/quick-start), [Tutorials](https://developers.refinitiv.com/eikon-apis/eikon-data-api/learning), [Documentation](https://developers.refinitiv.com/eikon-apis/eikon-data-api/docs) and much more.
#
# #### About the "eikon" module of the Refinitiv Data Platform Library
# The "eikon" module of the Refinitiv Data Platform Library for Python embeds all functions of the classical Eikon Data API ("eikon" python library). This module works the same as the Eikon Data API and can be used by applications that need the best of the Eikon Data API while taking advantage of the latest features offered by the Refinitiv Data Platform Library for Python.
#
# #### Getting Help and Support
# If you have any questions regarding the API usage, please post them on the [Eikon Data API Q&A Forum](https://community.developers.thomsonreuters.com/spaces/92/index.html). The Refinitiv Developer Community will be happy to help.

# %% [markdown]
# ## Import the library and connect to Eikon or Refinitiv Workspace

# %%
import refinitiv.data.eikon as ek
from IPython.display import HTML

ek.set_app_key('1e5d227dd54a4efc8ff630df09dd314e4d44ce07')

# %% [markdown]
# ## Get News HeadLines

# %% [markdown]
# #### From the default News repository (NewsWire)

# %%
ek.get_news_headlines(query = 'AAPL.O', count=10)
# Out:
# Failed to decode response to json: <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01//EN" "http://www.w3.org/TR/html4/strict.dtd"><html><head><title>Sign In</title><meta http-equiv="X-UA-Compatible" content="IE=edge"/><meta http-equiv="content-type" content="text/html; charset=utf-8"/><META page=login><link rel="icon" href="../images/favicon.png"/><link rel="shortcut icon" href="../images/favicon.png"/><link rel="stylesheet" type="text/css" href="/auth/css/lunar_commonstyles_spr.css?v=_3.44.551.01"/><link rel="stylesheet" type="text/css" href="/auth/css/lunarrefinitiv_loginstyles_spr.css?v=_3.44.551.01"/><script type="text/javascript" src="/auth/js/signin_spr.js?v=_3.44.551.01"></script><script type="text/javascript" src="/js/as.js?v=_3.44.551.01"></script><script src="/auth/js/jquery-1.10.1.min.js"></script><meta name="viewport" content="width=device-width, initial-scale=1"><script type="text/javascript">function inIframe(){try{return window.self!==window.top}catch(e){return false}}function docReady(fn){if(document.readyState==="complete"||document.readyState==="interactive"){setTimeout(fn,1)}else{document.addEventListener("DOMContentLoaded",fn)}}docReady(function(){if(inIframe()){document.getElementsByClassName("close_btn").item(0).innerHTML=""}});var customMachineValue="";var logoutUrl;if(customMachineValue){logoutUrl=jQuery.parseJSON(customMachineValue).logoutUrl}if(logoutUrl){function closeWindow(){window.location=logoutUrl}}else{if(!isWorkspace()){function closeWindow(){window.history.back()}}};</script><link rel="preload" href="/auth/images/rw-loading.svg" as="image"><link rel="preload" href="/auth/images/language-arrow-down-hover.svg" as="image"><link rel="preload" href="/auth/images/language-arrow-down.svg" as="image"><link rel="preload" href="/auth/images/language-arrow-up.svg" as="image"><script src="/auth/js/jquery-1.10.1.min.js"></script><script src="/auth/js/jquery-as.js?v=_3.44.551.01"></script><script type='text/javascript'>function openHelpLink(){var link="https://my.refinitiv.com/content/mytr/en/productsupport.html";openNewPopUp(link)}function initial(){elementFocus("AAA-AS-SI1-SE003");$("#AAA-AS-SI1-SE008_Value").val("FALSE");$("#AAA-AS-SI1-SE008_CheckBox_TRUE").checkbox({"checkedValue":"TRUE"});$("#AAA-AS-SI1-SE009").click(asUtils.forwardClick("#AAA-AS-SI1-SE008_CheckBox_TRUE"));$("#AAA-AS-SI1-SE003").attr("placeholder","User ID:".slice(0,-1));$("#AAA-AS-SI1-SE006").attr("placeholder","Password:".slice(0,-1));document.onclick=function(e){if($(".language_select_hover").size()<=0){if($("#AAA-AS-SI-C005").css("display")!="none"){$("#AAA-AS-SI-C005").css("display","none");toggleArrow("AAA-AS-SI-C005","AAA-AS-SI-SE020")}}}};</script></head><body onload="initial()" style="overflow:hidden;"><div class='main'><div class="space_top"></div><div class="content_center"><div class="header"><div class='header_bar_right'><div class='close_btn'><a class="close_icon" id="AAA-AS-SI-SE023" href="javascript:closeWindow();" tabindex="-1"></a></div><div class="language_bar"><div class="language_box" onclick="onClickLanguageBox('AAA-AS-SI-C005');toggleArrow('AAA-AS-SI-C005', 'AAA-AS-SI-SE020');" onkeydown="return onPressLanguageBox(event, 'AAA-AS-SI-C005');"><div class="language_select" onmouseover='changeHover(this,"language_select",true)' onmouseout='changeHover(this,"language_select",false)' onfocus='changeHover(this,"language_select",true)' onblur='changeHover(this,"language_select",false)' tabIndex="8"><div class="language_text" id='AAA-AS-SI-SE020'>English
# </div></div><div id="AAA-AS-SI-C005" class="language_list_box"><a id="en-US" class="language_item" onclick="onSelectLanguage('en-US', '/auth/UI/Login?MajorVersion=1&ProviderID=https%3A%2F%2Femea1.proxy.cp.thomsonreuters.com%3A443%2Famagent&RequestID=98AAF5304CD0714AA62C405406D3D7FAEC0F48A6EB7C1BA87BEA6C385C22CC97&MinorVersion=0&theme=charcoal&IssueInstant=2023-07-04T19%3A04%3A14Z&product=refinitiv&goto=%2Fauth%2Fcdcservlet%3FTARGET%3Dhttps%253A%252F%252Femea1.apps.cp.thomsonreuters.com%252FApps%252FUDF%252FMSF%253Fampostpreserve%253D3b4743fc-5244-3f46-86a4-a31695adee9a%2526srv%253DDTCP-ERPCPRP07%26MajorVersion%3D1%26ProviderID%3Dhttps%253A%252F%252Femea1.proxy.cp.thomsonreuters.com%253A443%252Famagent%26RequestID%3D98AAF5304CD0714AA62C405406D3D7FAEC0F48A6EB7C1BA87BEA6C385C22CC97%26MinorVersion%3D0%26theme%3Dcharcoal%26IssueInstant%3D2023-07-04T19%253A04%253A14Z%26product%3Drefinitiv%26locale%3Den-US&locale=en-US' ,'AAA-AS-SI-C005', 'AAA-AS-SI-C004', 'AAA-AS-SI-SE020')" href="#" tabIndex='-1'> English </a><a id="ja-JP" class="language_item" onclick="onSelectLanguage('ja-JP', '/auth/UI/Login?MajorVersion=1&ProviderID=https%3A%2F%2Femea1.proxy.cp.thomsonreuters.com%3A443%2Famagent&RequestID=98AAF5304CD0714AA62C405406D3D7FAEC0F48A6EB7C1BA87BEA6C385C22CC97&MinorVersion=0&theme=charcoal&IssueInstant=2023-07-04T19%3A04%3A14Z&product=refinitiv&goto=%2Fauth%2Fcdcservlet%3FTARGET%3Dhttps%253A%252F%252Femea1.apps.cp.thomsonreuters.com%252FApps%252FUDF%252FMSF%253Fampostpreserve%253D3b4743fc-5244-3f46-86a4-a31695adee9a%2526srv%253DDTCP-ERPCPRP07%26MajorVersion%3D1%26ProviderID%3Dhttps%253A%252F%252Femea1.proxy.cp.thomsonreuters.com%253A443%252Famagent%26RequestID%3D98AAF5304CD0714AA62C405406D3D7FAEC0F48A6EB7C1BA87BEA6C385C22CC97%26MinorVersion%3D0%26theme%3Dcharcoal%26IssueInstant%3D2023-07-04T19%253A04%253A14Z%26product%3Drefinitiv%26locale%3Dja-JP&locale=ja-JP' ,'AAA-AS-SI-C005', 'AAA-AS-SI-C004', 'AAA-AS-SI-SE020')" href="#" tabIndex='-1'> 日本語 </a><a id="zh-CN" class="language_item" onclick="onSelectLanguage('zh-CN', '/auth/UI/Login?MajorVersion=1&ProviderID=https%3A%2F%2Femea1.proxy.cp.thomsonreuters.com%3A443%2Famagent&RequestID=98AAF5304CD0714AA62C405406D3D7FAEC0F48A6EB7C1BA87BEA6C385C22CC97&MinorVersion=0&theme=charcoal&IssueInstant=2023-07-04T19%3A04%3A14Z&product=refinitiv&goto=%2Fauth%2Fcdcservlet%3FTARGET%3Dhttps%253A%252F%252Femea1.apps.cp.thomsonreuters.com%252FApps%252FUDF%252FMSF%253Fampostpreserve%253D3b4743fc-5244-3f46-86a4-a31695adee9a%2526srv%253DDTCP-ERPCPRP07%26MajorVersion%3D1%26ProviderID%3Dhttps%253A%252F%252Femea1.proxy.cp.thomsonreuters.com%253A443%252Famagent%26RequestID%3D98AAF5304CD0714AA62C405406D3D7FAEC0F48A6EB7C1BA87BEA6C385C22CC97%26MinorVersion%3D0%26theme%3Dcharcoal%26IssueInstant%3D2023-07-04T19%253A04%253A14Z%26product%3Drefinitiv%26locale%3Dzh-CN&locale=zh-CN' ,'AAA-AS-SI-C005', 'AAA-AS-SI-C004', 'AAA-AS-SI-SE020')" href="#" tabIndex='-1'> 中文简体 </a></div><input class='hiddensubmit' type="hidden" id="AAA-AS-SI-C004" name="AAA-AS-SI-C004" value="en-US"/></div><script>function toggleArrow(dropdownId,toggleId){var el=document.getElementById(dropdownId);var toggleBox=document.getElementById(toggleId);if(el.style.display=="block"){toggleBox.classList.add("language-arrow-up")}else{toggleBox.classList.remove("language-arrow-up")}};</script></div></div></div><div class="body_main"><div class="signin_body_content"><div class="body_brand"><div id="AAA-AS-SI-SE006" class="product_brand_image"></div></div><div class="body_input"><form name="frmSignIn" action="blank" onSubmit="return defaultSubmitLoading('AAA-AS-SI1-SE014')" method="post"><table width='100%' cellspacing="1" cellpadding="0" border="0"><tr class='signin_input_row'><td width='76px'><label class='topic_txt' id="AAA-AS-SI1-SE002" for='IDToken1'> User ID: </label></td><td><div class="textbox_img textbox_img_big2"><input type="text" id="AAA-AS-SI1-SE003" name="IDToken1" placeholder="User ID" value="" autocomplete="off" tabIndex='1'/></div></td></tr><tr cl ...
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# /var/folders/cv/_19ylw5j4hsbq7ctdf273z3m0000gn/T/ipykernel_49667/1543726311.py in <module>
# ----> 1 ek.get_news_headlines(query = 'AAPL.O', count=10)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/refinitiv/data/eikon/_news_request.py in get_news_headlines(query, count, repository, date_from, date_to, raw_output, debug)
#     152
#     153     response = json_requests.send_json_request(News_Headlines_UDF_endpoint, payload, debug=debug)
# --> 154     result = response.json()
#     155
#     156     if raw_output:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/httpx/_models.py in json(self, **kwargs)
#     741             if encoding is not None:
#     742                 return jsonlib.loads(self.content.decode(encoding), **kwargs)
# --> 743         return jsonlib.loads(self.text, **kwargs)
#     744
#     745     @property
#
# ~/opt/anaconda3/lib/python3.9/json/__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     344             parse_int is None and parse_float is None and
#     345             parse_constant is None and object_pairs_hook is None and not kw):
# --> 346         return _default_decoder.decode(s)
#     347     if cls is None:
#     348         cls = JSONDecoder
#
# ~/opt/anaconda3/lib/python3.9/json/decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# ~/opt/anaconda3/lib/python3.9/json/decoder.py in raw_decode(self, s, idx)
#     353             obj, end = self.scan_once(s, idx)
#     354         except StopIteration as err:
# --> 355             raise JSONDecodeError("Expecting value", s, err.value) from None
#     356         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %% [markdown]
# #### From the other News repository (NewsRoom and WebNews)

# %%
ek.get_news_headlines(query = 'AAPL.O', repository='NewsRoom')
# Out:
# Failed to decode response to json: <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01//EN" "http://www.w3.org/TR/html4/strict.dtd"><html><head><title>Sign In</title><meta http-equiv="X-UA-Compatible" content="IE=edge"/><meta http-equiv="content-type" content="text/html; charset=utf-8"/><META page=login><link rel="icon" href="../images/favicon.png"/><link rel="shortcut icon" href="../images/favicon.png"/><link rel="stylesheet" type="text/css" href="/auth/css/lunar_commonstyles_spr.css?v=_3.44.551.01"/><link rel="stylesheet" type="text/css" href="/auth/css/lunarrefinitiv_loginstyles_spr.css?v=_3.44.551.01"/><script type="text/javascript" src="/auth/js/signin_spr.js?v=_3.44.551.01"></script><script type="text/javascript" src="/js/as.js?v=_3.44.551.01"></script><script src="/auth/js/jquery-1.10.1.min.js"></script><meta name="viewport" content="width=device-width, initial-scale=1"><script type="text/javascript">function inIframe(){try{return window.self!==window.top}catch(e){return false}}function docReady(fn){if(document.readyState==="complete"||document.readyState==="interactive"){setTimeout(fn,1)}else{document.addEventListener("DOMContentLoaded",fn)}}docReady(function(){if(inIframe()){document.getElementsByClassName("close_btn").item(0).innerHTML=""}});var customMachineValue="";var logoutUrl;if(customMachineValue){logoutUrl=jQuery.parseJSON(customMachineValue).logoutUrl}if(logoutUrl){function closeWindow(){window.location=logoutUrl}}else{if(!isWorkspace()){function closeWindow(){window.history.back()}}};</script><link rel="preload" href="/auth/images/rw-loading.svg" as="image"><link rel="preload" href="/auth/images/language-arrow-down-hover.svg" as="image"><link rel="preload" href="/auth/images/language-arrow-down.svg" as="image"><link rel="preload" href="/auth/images/language-arrow-up.svg" as="image"><script src="/auth/js/jquery-1.10.1.min.js"></script><script src="/auth/js/jquery-as.js?v=_3.44.551.01"></script><script type='text/javascript'>function openHelpLink(){var link="https://my.refinitiv.com/content/mytr/en/productsupport.html";openNewPopUp(link)}function initial(){elementFocus("AAA-AS-SI1-SE003");$("#AAA-AS-SI1-SE008_Value").val("FALSE");$("#AAA-AS-SI1-SE008_CheckBox_TRUE").checkbox({"checkedValue":"TRUE"});$("#AAA-AS-SI1-SE009").click(asUtils.forwardClick("#AAA-AS-SI1-SE008_CheckBox_TRUE"));$("#AAA-AS-SI1-SE003").attr("placeholder","User ID:".slice(0,-1));$("#AAA-AS-SI1-SE006").attr("placeholder","Password:".slice(0,-1));document.onclick=function(e){if($(".language_select_hover").size()<=0){if($("#AAA-AS-SI-C005").css("display")!="none"){$("#AAA-AS-SI-C005").css("display","none");toggleArrow("AAA-AS-SI-C005","AAA-AS-SI-SE020")}}}};</script></head><body onload="initial()" style="overflow:hidden;"><div class='main'><div class="space_top"></div><div class="content_center"><div class="header"><div class='header_bar_right'><div class='close_btn'><a class="close_icon" id="AAA-AS-SI-SE023" href="javascript:closeWindow();" tabindex="-1"></a></div><div class="language_bar"><div class="language_box" onclick="onClickLanguageBox('AAA-AS-SI-C005');toggleArrow('AAA-AS-SI-C005', 'AAA-AS-SI-SE020');" onkeydown="return onPressLanguageBox(event, 'AAA-AS-SI-C005');"><div class="language_select" onmouseover='changeHover(this,"language_select",true)' onmouseout='changeHover(this,"language_select",false)' onfocus='changeHover(this,"language_select",true)' onblur='changeHover(this,"language_select",false)' tabIndex="8"><div class="language_text" id='AAA-AS-SI-SE020'>English
# </div></div><div id="AAA-AS-SI-C005" class="language_list_box"><a id="en-US" class="language_item" onclick="onSelectLanguage('en-US', '/auth/UI/Login?MajorVersion=1&ProviderID=https%3A%2F%2Femea1.proxy.cp.thomsonreuters.com%3A443%2Famagent&RequestID=5DB3D0086170E8CDDA27695B7798AC6C365E2CE349A7574B4782226FBF2BB2DE&MinorVersion=0&theme=charcoal&IssueInstant=2023-07-04T19%3A04%3A32Z&product=refinitiv&goto=%2Fauth%2Fcdcservlet%3FTARGET%3Dhttps%253A%252F%252Femea1.apps.cp.thomsonreuters.com%252FApps%252FUDF%252FMSF%253Fampostpreserve%253Df5d3b3d5-10b6-0f4d-8e83-1ed13749a784%2526srv%253DDTCP-ERPCPRP04%26MajorVersion%3D1%26ProviderID%3Dhttps%253A%252F%252Femea1.proxy.cp.thomsonreuters.com%253A443%252Famagent%26RequestID%3D5DB3D0086170E8CDDA27695B7798AC6C365E2CE349A7574B4782226FBF2BB2DE%26MinorVersion%3D0%26theme%3Dcharcoal%26IssueInstant%3D2023-07-04T19%253A04%253A32Z%26product%3Drefinitiv%26locale%3Den-US&locale=en-US' ,'AAA-AS-SI-C005', 'AAA-AS-SI-C004', 'AAA-AS-SI-SE020')" href="#" tabIndex='-1'> English </a><a id="ja-JP" class="language_item" onclick="onSelectLanguage('ja-JP', '/auth/UI/Login?MajorVersion=1&ProviderID=https%3A%2F%2Femea1.proxy.cp.thomsonreuters.com%3A443%2Famagent&RequestID=5DB3D0086170E8CDDA27695B7798AC6C365E2CE349A7574B4782226FBF2BB2DE&MinorVersion=0&theme=charcoal&IssueInstant=2023-07-04T19%3A04%3A32Z&product=refinitiv&goto=%2Fauth%2Fcdcservlet%3FTARGET%3Dhttps%253A%252F%252Femea1.apps.cp.thomsonreuters.com%252FApps%252FUDF%252FMSF%253Fampostpreserve%253Df5d3b3d5-10b6-0f4d-8e83-1ed13749a784%2526srv%253DDTCP-ERPCPRP04%26MajorVersion%3D1%26ProviderID%3Dhttps%253A%252F%252Femea1.proxy.cp.thomsonreuters.com%253A443%252Famagent%26RequestID%3D5DB3D0086170E8CDDA27695B7798AC6C365E2CE349A7574B4782226FBF2BB2DE%26MinorVersion%3D0%26theme%3Dcharcoal%26IssueInstant%3D2023-07-04T19%253A04%253A32Z%26product%3Drefinitiv%26locale%3Dja-JP&locale=ja-JP' ,'AAA-AS-SI-C005', 'AAA-AS-SI-C004', 'AAA-AS-SI-SE020')" href="#" tabIndex='-1'> 日本語 </a><a id="zh-CN" class="language_item" onclick="onSelectLanguage('zh-CN', '/auth/UI/Login?MajorVersion=1&ProviderID=https%3A%2F%2Femea1.proxy.cp.thomsonreuters.com%3A443%2Famagent&RequestID=5DB3D0086170E8CDDA27695B7798AC6C365E2CE349A7574B4782226FBF2BB2DE&MinorVersion=0&theme=charcoal&IssueInstant=2023-07-04T19%3A04%3A32Z&product=refinitiv&goto=%2Fauth%2Fcdcservlet%3FTARGET%3Dhttps%253A%252F%252Femea1.apps.cp.thomsonreuters.com%252FApps%252FUDF%252FMSF%253Fampostpreserve%253Df5d3b3d5-10b6-0f4d-8e83-1ed13749a784%2526srv%253DDTCP-ERPCPRP04%26MajorVersion%3D1%26ProviderID%3Dhttps%253A%252F%252Femea1.proxy.cp.thomsonreuters.com%253A443%252Famagent%26RequestID%3D5DB3D0086170E8CDDA27695B7798AC6C365E2CE349A7574B4782226FBF2BB2DE%26MinorVersion%3D0%26theme%3Dcharcoal%26IssueInstant%3D2023-07-04T19%253A04%253A32Z%26product%3Drefinitiv%26locale%3Dzh-CN&locale=zh-CN' ,'AAA-AS-SI-C005', 'AAA-AS-SI-C004', 'AAA-AS-SI-SE020')" href="#" tabIndex='-1'> 中文简体 </a></div><input class='hiddensubmit' type="hidden" id="AAA-AS-SI-C004" name="AAA-AS-SI-C004" value="en-US"/></div><script>function toggleArrow(dropdownId,toggleId){var el=document.getElementById(dropdownId);var toggleBox=document.getElementById(toggleId);if(el.style.display=="block"){toggleBox.classList.add("language-arrow-up")}else{toggleBox.classList.remove("language-arrow-up")}};</script></div></div></div><div class="body_main"><div class="signin_body_content"><div class="body_brand"><div id="AAA-AS-SI-SE006" class="product_brand_image"></div></div><div class="body_input"><form name="frmSignIn" action="blank" onSubmit="return defaultSubmitLoading('AAA-AS-SI1-SE014')" method="post"><table width='100%' cellspacing="1" cellpadding="0" border="0"><tr class='signin_input_row'><td width='76px'><label class='topic_txt' id="AAA-AS-SI1-SE002" for='IDToken1'> User ID: </label></td><td><div class="textbox_img textbox_img_big2"><input type="text" id="AAA-AS-SI1-SE003" name="IDToken1" placeholder="User ID" value="" autocomplete="off" tabIndex='1'/></div></td></tr><tr cl ...
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# /var/folders/cv/_19ylw5j4hsbq7ctdf273z3m0000gn/T/ipykernel_49667/377273094.py in <module>
# ----> 1 ek.get_news_headlines(query = 'AAPL.O', repository='NewsRoom')
#
# ~/opt/anaconda3/lib/python3.9/site-packages/refinitiv/data/eikon/_news_request.py in get_news_headlines(query, count, repository, date_from, date_to, raw_output, debug)
#     152
#     153     response = json_requests.send_json_request(News_Headlines_UDF_endpoint, payload, debug=debug)
# --> 154     result = response.json()
#     155
#     156     if raw_output:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/httpx/_models.py in json(self, **kwargs)
#     741             if encoding is not None:
#     742                 return jsonlib.loads(self.content.decode(encoding), **kwargs)
# --> 743         return jsonlib.loads(self.text, **kwargs)
#     744
#     745     @property
#
# ~/opt/anaconda3/lib/python3.9/json/__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     344             parse_int is None and parse_float is None and
#     345             parse_constant is None and object_pairs_hook is None and not kw):
# --> 346         return _default_decoder.decode(s)
#     347     if cls is None:
#     348         cls = JSONDecoder
#
# ~/opt/anaconda3/lib/python3.9/json/decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# ~/opt/anaconda3/lib/python3.9/json/decoder.py in raw_decode(self, s, idx)
#     353             obj, end = self.scan_once(s, idx)
#     354         except StopIteration as err:
# --> 355             raise JSONDecodeError("Expecting value", s, err.value) from None
#     356         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
ek.get_news_headlines(query = 'AAPL.O', repository='WebNews')
# Out:
# Failed to decode response to json: <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01//EN" "http://www.w3.org/TR/html4/strict.dtd"><html><head><title>Sign In</title><meta http-equiv="X-UA-Compatible" content="IE=edge"/><meta http-equiv="content-type" content="text/html; charset=utf-8"/><META page=login><link rel="icon" href="../images/favicon.png"/><link rel="shortcut icon" href="../images/favicon.png"/><link rel="stylesheet" type="text/css" href="/auth/css/lunar_commonstyles_spr.css?v=_3.44.551.01"/><link rel="stylesheet" type="text/css" href="/auth/css/lunarrefinitiv_loginstyles_spr.css?v=_3.44.551.01"/><script type="text/javascript" src="/auth/js/signin_spr.js?v=_3.44.551.01"></script><script type="text/javascript" src="/js/as.js?v=_3.44.551.01"></script><script src="/auth/js/jquery-1.10.1.min.js"></script><meta name="viewport" content="width=device-width, initial-scale=1"><script type="text/javascript">function inIframe(){try{return window.self!==window.top}catch(e){return false}}function docReady(fn){if(document.readyState==="complete"||document.readyState==="interactive"){setTimeout(fn,1)}else{document.addEventListener("DOMContentLoaded",fn)}}docReady(function(){if(inIframe()){document.getElementsByClassName("close_btn").item(0).innerHTML=""}});var customMachineValue="";var logoutUrl;if(customMachineValue){logoutUrl=jQuery.parseJSON(customMachineValue).logoutUrl}if(logoutUrl){function closeWindow(){window.location=logoutUrl}}else{if(!isWorkspace()){function closeWindow(){window.history.back()}}};</script><link rel="preload" href="/auth/images/rw-loading.svg" as="image"><link rel="preload" href="/auth/images/language-arrow-down-hover.svg" as="image"><link rel="preload" href="/auth/images/language-arrow-down.svg" as="image"><link rel="preload" href="/auth/images/language-arrow-up.svg" as="image"><script src="/auth/js/jquery-1.10.1.min.js"></script><script src="/auth/js/jquery-as.js?v=_3.44.551.01"></script><script type='text/javascript'>function openHelpLink(){var link="https://my.refinitiv.com/content/mytr/en/productsupport.html";openNewPopUp(link)}function initial(){elementFocus("AAA-AS-SI1-SE003");$("#AAA-AS-SI1-SE008_Value").val("FALSE");$("#AAA-AS-SI1-SE008_CheckBox_TRUE").checkbox({"checkedValue":"TRUE"});$("#AAA-AS-SI1-SE009").click(asUtils.forwardClick("#AAA-AS-SI1-SE008_CheckBox_TRUE"));$("#AAA-AS-SI1-SE003").attr("placeholder","User ID:".slice(0,-1));$("#AAA-AS-SI1-SE006").attr("placeholder","Password:".slice(0,-1));document.onclick=function(e){if($(".language_select_hover").size()<=0){if($("#AAA-AS-SI-C005").css("display")!="none"){$("#AAA-AS-SI-C005").css("display","none");toggleArrow("AAA-AS-SI-C005","AAA-AS-SI-SE020")}}}};</script></head><body onload="initial()" style="overflow:hidden;"><div class='main'><div class="space_top"></div><div class="content_center"><div class="header"><div class='header_bar_right'><div class='close_btn'><a class="close_icon" id="AAA-AS-SI-SE023" href="javascript:closeWindow();" tabindex="-1"></a></div><div class="language_bar"><div class="language_box" onclick="onClickLanguageBox('AAA-AS-SI-C005');toggleArrow('AAA-AS-SI-C005', 'AAA-AS-SI-SE020');" onkeydown="return onPressLanguageBox(event, 'AAA-AS-SI-C005');"><div class="language_select" onmouseover='changeHover(this,"language_select",true)' onmouseout='changeHover(this,"language_select",false)' onfocus='changeHover(this,"language_select",true)' onblur='changeHover(this,"language_select",false)' tabIndex="8"><div class="language_text" id='AAA-AS-SI-SE020'>English
# </div></div><div id="AAA-AS-SI-C005" class="language_list_box"><a id="en-US" class="language_item" onclick="onSelectLanguage('en-US', '/auth/UI/Login?MajorVersion=1&ProviderID=https%3A%2F%2Femea1.proxy.cp.thomsonreuters.com%3A443%2Famagent&RequestID=DCA96A5A0920DAF1749E41FCBB2ABB00BA4142BF4A59F6E7E9FD498A90AA770C&MinorVersion=0&theme=charcoal&IssueInstant=2023-07-04T19%3A04%3A50Z&product=refinitiv&goto=%2Fauth%2Fcdcservlet%3FTARGET%3Dhttps%253A%252F%252Femea1.apps.cp.thomsonreuters.com%252FApps%252FUDF%252FMSF%253Fampostpreserve%253D409cdace-15ed-e04e-9244-457e071cb7f0%2526srv%253DDTCP-ERPCPRP08%26MajorVersion%3D1%26ProviderID%3Dhttps%253A%252F%252Femea1.proxy.cp.thomsonreuters.com%253A443%252Famagent%26RequestID%3DDCA96A5A0920DAF1749E41FCBB2ABB00BA4142BF4A59F6E7E9FD498A90AA770C%26MinorVersion%3D0%26theme%3Dcharcoal%26IssueInstant%3D2023-07-04T19%253A04%253A50Z%26product%3Drefinitiv%26locale%3Den-US&locale=en-US' ,'AAA-AS-SI-C005', 'AAA-AS-SI-C004', 'AAA-AS-SI-SE020')" href="#" tabIndex='-1'> English </a><a id="ja-JP" class="language_item" onclick="onSelectLanguage('ja-JP', '/auth/UI/Login?MajorVersion=1&ProviderID=https%3A%2F%2Femea1.proxy.cp.thomsonreuters.com%3A443%2Famagent&RequestID=DCA96A5A0920DAF1749E41FCBB2ABB00BA4142BF4A59F6E7E9FD498A90AA770C&MinorVersion=0&theme=charcoal&IssueInstant=2023-07-04T19%3A04%3A50Z&product=refinitiv&goto=%2Fauth%2Fcdcservlet%3FTARGET%3Dhttps%253A%252F%252Femea1.apps.cp.thomsonreuters.com%252FApps%252FUDF%252FMSF%253Fampostpreserve%253D409cdace-15ed-e04e-9244-457e071cb7f0%2526srv%253DDTCP-ERPCPRP08%26MajorVersion%3D1%26ProviderID%3Dhttps%253A%252F%252Femea1.proxy.cp.thomsonreuters.com%253A443%252Famagent%26RequestID%3DDCA96A5A0920DAF1749E41FCBB2ABB00BA4142BF4A59F6E7E9FD498A90AA770C%26MinorVersion%3D0%26theme%3Dcharcoal%26IssueInstant%3D2023-07-04T19%253A04%253A50Z%26product%3Drefinitiv%26locale%3Dja-JP&locale=ja-JP' ,'AAA-AS-SI-C005', 'AAA-AS-SI-C004', 'AAA-AS-SI-SE020')" href="#" tabIndex='-1'> 日本語 </a><a id="zh-CN" class="language_item" onclick="onSelectLanguage('zh-CN', '/auth/UI/Login?MajorVersion=1&ProviderID=https%3A%2F%2Femea1.proxy.cp.thomsonreuters.com%3A443%2Famagent&RequestID=DCA96A5A0920DAF1749E41FCBB2ABB00BA4142BF4A59F6E7E9FD498A90AA770C&MinorVersion=0&theme=charcoal&IssueInstant=2023-07-04T19%3A04%3A50Z&product=refinitiv&goto=%2Fauth%2Fcdcservlet%3FTARGET%3Dhttps%253A%252F%252Femea1.apps.cp.thomsonreuters.com%252FApps%252FUDF%252FMSF%253Fampostpreserve%253D409cdace-15ed-e04e-9244-457e071cb7f0%2526srv%253DDTCP-ERPCPRP08%26MajorVersion%3D1%26ProviderID%3Dhttps%253A%252F%252Femea1.proxy.cp.thomsonreuters.com%253A443%252Famagent%26RequestID%3DDCA96A5A0920DAF1749E41FCBB2ABB00BA4142BF4A59F6E7E9FD498A90AA770C%26MinorVersion%3D0%26theme%3Dcharcoal%26IssueInstant%3D2023-07-04T19%253A04%253A50Z%26product%3Drefinitiv%26locale%3Dzh-CN&locale=zh-CN' ,'AAA-AS-SI-C005', 'AAA-AS-SI-C004', 'AAA-AS-SI-SE020')" href="#" tabIndex='-1'> 中文简体 </a></div><input class='hiddensubmit' type="hidden" id="AAA-AS-SI-C004" name="AAA-AS-SI-C004" value="en-US"/></div><script>function toggleArrow(dropdownId,toggleId){var el=document.getElementById(dropdownId);var toggleBox=document.getElementById(toggleId);if(el.style.display=="block"){toggleBox.classList.add("language-arrow-up")}else{toggleBox.classList.remove("language-arrow-up")}};</script></div></div></div><div class="body_main"><div class="signin_body_content"><div class="body_brand"><div id="AAA-AS-SI-SE006" class="product_brand_image"></div></div><div class="body_input"><form name="frmSignIn" action="blank" onSubmit="return defaultSubmitLoading('AAA-AS-SI1-SE014')" method="post"><table width='100%' cellspacing="1" cellpadding="0" border="0"><tr class='signin_input_row'><td width='76px'><label class='topic_txt' id="AAA-AS-SI1-SE002" for='IDToken1'> User ID: </label></td><td><div class="textbox_img textbox_img_big2"><input type="text" id="AAA-AS-SI1-SE003" name="IDToken1" placeholder="User ID" value="" autocomplete="off" tabIndex='1'/></div></td></tr><tr cl ...
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# /var/folders/cv/_19ylw5j4hsbq7ctdf273z3m0000gn/T/ipykernel_49667/3479322377.py in <module>
# ----> 1 ek.get_news_headlines(query = 'AAPL.O', repository='WebNews')
#
# ~/opt/anaconda3/lib/python3.9/site-packages/refinitiv/data/eikon/_news_request.py in get_news_headlines(query, count, repository, date_from, date_to, raw_output, debug)
#     152
#     153     response = json_requests.send_json_request(News_Headlines_UDF_endpoint, payload, debug=debug)
# --> 154     result = response.json()
#     155
#     156     if raw_output:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/httpx/_models.py in json(self, **kwargs)
#     741             if encoding is not None:
#     742                 return jsonlib.loads(self.content.decode(encoding), **kwargs)
# --> 743         return jsonlib.loads(self.text, **kwargs)
#     744
#     745     @property
#
# ~/opt/anaconda3/lib/python3.9/json/__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     344             parse_int is None and parse_float is None and
#     345             parse_constant is None and object_pairs_hook is None and not kw):
# --> 346         return _default_decoder.decode(s)
#     347     if cls is None:
#     348         cls = JSONDecoder
#
# ~/opt/anaconda3/lib/python3.9/json/decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# ~/opt/anaconda3/lib/python3.9/json/decoder.py in raw_decode(self, s, idx)
#     353             obj, end = self.scan_once(s, idx)
#     354         except StopIteration as err:
# --> 355             raise JSONDecodeError("Expecting value", s, err.value) from None
#     356         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
ek.get_news_headlines(query = 'AAPL.O', repository='WebNews,NewsRoom,NewsWire')
# Out:
#                                           versionCreated  \
# 2021-12-17 14:49:00.000        2021-12-17 14:49:00+00:00
# 2021-12-17 14:03:04.581 2021-12-17 14:03:04.581000+00:00
# 2021-12-17 13:01:22.000        2021-12-17 13:01:22+00:00
# 2021-12-17 11:37:49.000        2021-12-17 12:57:24+00:00
# 2021-12-17 12:50:19.000        2021-12-17 12:50:19+00:00
# 2021-12-17 11:37:03.087 2021-12-17 11:37:05.399000+00:00
# 2021-12-17 11:27:57.229 2021-12-17 11:27:57.851000+00:00
# 2021-12-17 11:23:14.422 2021-12-17 11:23:14.756000+00:00
# 2021-12-17 11:22:03.516 2021-12-17 11:22:09.074000+00:00
# 2021-12-17 11:22:03.501 2021-12-17 11:22:08.970000+00:00
#
#                                                                       text  \
# 2021-12-17 14:49:00.000  BOURSE-Wall Street ouvre en baisse, les "techs...
# 2021-12-17 14:03:04.581  NEW YORK: TERMINER PÅ MINUS, TECHSEKTORN UNDER...
# 2021-12-17 13:01:22.000  US STOCKS-Фьючерсы на Nasdaq падают на фоне сн...
# 2021-12-17 11:37:49.000  USA-Les valeurs à suivre à Wall Street (actual...
# 2021-12-17 12:50:19.000  BOLSA EUA-Futuros do Nasdaq 100 caem pressiona...
# 2021-12-17 11:37:03.087  Cardan Capital Partners LLC Trims Position in ...
# 2021-12-17 11:27:57.229                    小米失算了,"国产黑马"25分钟销售额破亿,苹果13也不是对手
# 2021-12-17 11:23:14.422  DRAMATISCHE MARKTENTWICKLUNG! Apple Aktie – Er...
# 2021-12-17 11:22:03.516  Apple (AAPL) issued patent titled "Services Pr...
# 2021-12-17 11:22:03.501  Apple (AAPL) issued patent titled "Attachment ...
#
#                                                               storyId  \
# 2021-12-17 14:49:00.000  urn:newsml:reuters.com:20211217:nL8N2T24NS:2
# 2021-12-17 14:03:04.581  urn:newsml:reuters.com:20211217:nDIR1yNjJG:1
# 2021-12-17 13:01:22.000  urn:newsml:reuters.com:20211217:nL8N2T23U7:1
# 2021-12-17 11:37:49.000  urn:newsml:reuters.com:20211217:nL8N2T22P9:3
# 2021-12-17 12:50:19.000  urn:newsml:reuters.com:20211217:nL1N2T20XL:1
# 2021-12-17 11:37:03.087     urn:newsml:newsroom:20211217:nNRAigvpkp:0
# 2021-12-17 11:27:57.229        urn:link:webnews:20211217:nNRAigvntq:0
# 2021-12-17 11:23:14.422        urn:link:webnews:20211217:nNRAigvmtx:0
# 2021-12-17 11:22:03.516     urn:newsml:newsroom:20211217:nNRAigvm62:0
# 2021-12-17 11:22:03.501     urn:newsml:newsroom:20211217:nNRAigvgov:0
#
#                         sourceCode
# 2021-12-17 14:49:00.000    NS:RTRS
# 2021-12-17 14:03:04.581     NS:DIR
# 2021-12-17 13:01:22.000    NS:RTRS
# 2021-12-17 11:37:49.000    NS:RTRS
# 2021-12-17 12:50:19.000    NS:RTRS
# 2021-12-17 11:37:03.087  NS:WATNEW
# 2021-12-17 11:27:57.229  NS:NETEAS
# 2021-12-17 11:23:14.422  NS:WALONL
# 2021-12-17 11:22:03.516  NS:NEWUSN
# 2021-12-17 11:22:03.501  NS:NEWUSN

# %% [markdown]
# ## Get News Story

# %% [markdown]
# #### Get the Story ID of the first headline for Apple

# %%
headlines = ek.get_news_headlines('AAPL.O',1)
story_id = headlines.iat[0,2]
story_id
# Out:
# Failed to decode response to json: <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01//EN" "http://www.w3.org/TR/html4/strict.dtd"><html><head><title>Sign In</title><meta http-equiv="X-UA-Compatible" content="IE=edge"/><meta http-equiv="content-type" content="text/html; charset=utf-8"/><META page=login><link rel="icon" href="../images/favicon.png"/><link rel="shortcut icon" href="../images/favicon.png"/><link rel="stylesheet" type="text/css" href="/auth/css/lunar_commonstyles_spr.css?v=_3.44.551.01"/><link rel="stylesheet" type="text/css" href="/auth/css/lunarrefinitiv_loginstyles_spr.css?v=_3.44.551.01"/><script type="text/javascript" src="/auth/js/signin_spr.js?v=_3.44.551.01"></script><script type="text/javascript" src="/js/as.js?v=_3.44.551.01"></script><script src="/auth/js/jquery-1.10.1.min.js"></script><meta name="viewport" content="width=device-width, initial-scale=1"><script type="text/javascript">function inIframe(){try{return window.self!==window.top}catch(e){return false}}function docReady(fn){if(document.readyState==="complete"||document.readyState==="interactive"){setTimeout(fn,1)}else{document.addEventListener("DOMContentLoaded",fn)}}docReady(function(){if(inIframe()){document.getElementsByClassName("close_btn").item(0).innerHTML=""}});var customMachineValue="";var logoutUrl;if(customMachineValue){logoutUrl=jQuery.parseJSON(customMachineValue).logoutUrl}if(logoutUrl){function closeWindow(){window.location=logoutUrl}}else{if(!isWorkspace()){function closeWindow(){window.history.back()}}};</script><link rel="preload" href="/auth/images/rw-loading.svg" as="image"><link rel="preload" href="/auth/images/language-arrow-down-hover.svg" as="image"><link rel="preload" href="/auth/images/language-arrow-down.svg" as="image"><link rel="preload" href="/auth/images/language-arrow-up.svg" as="image"><script src="/auth/js/jquery-1.10.1.min.js"></script><script src="/auth/js/jquery-as.js?v=_3.44.551.01"></script><script type='text/javascript'>function openHelpLink(){var link="https://my.refinitiv.com/content/mytr/en/productsupport.html";openNewPopUp(link)}function initial(){elementFocus("AAA-AS-SI1-SE003");$("#AAA-AS-SI1-SE008_Value").val("FALSE");$("#AAA-AS-SI1-SE008_CheckBox_TRUE").checkbox({"checkedValue":"TRUE"});$("#AAA-AS-SI1-SE009").click(asUtils.forwardClick("#AAA-AS-SI1-SE008_CheckBox_TRUE"));$("#AAA-AS-SI1-SE003").attr("placeholder","User ID:".slice(0,-1));$("#AAA-AS-SI1-SE006").attr("placeholder","Password:".slice(0,-1));document.onclick=function(e){if($(".language_select_hover").size()<=0){if($("#AAA-AS-SI-C005").css("display")!="none"){$("#AAA-AS-SI-C005").css("display","none");toggleArrow("AAA-AS-SI-C005","AAA-AS-SI-SE020")}}}};</script></head><body onload="initial()" style="overflow:hidden;"><div class='main'><div class="space_top"></div><div class="content_center"><div class="header"><div class='header_bar_right'><div class='close_btn'><a class="close_icon" id="AAA-AS-SI-SE023" href="javascript:closeWindow();" tabindex="-1"></a></div><div class="language_bar"><div class="language_box" onclick="onClickLanguageBox('AAA-AS-SI-C005');toggleArrow('AAA-AS-SI-C005', 'AAA-AS-SI-SE020');" onkeydown="return onPressLanguageBox(event, 'AAA-AS-SI-C005');"><div class="language_select" onmouseover='changeHover(this,"language_select",true)' onmouseout='changeHover(this,"language_select",false)' onfocus='changeHover(this,"language_select",true)' onblur='changeHover(this,"language_select",false)' tabIndex="8"><div class="language_text" id='AAA-AS-SI-SE020'>English
# </div></div><div id="AAA-AS-SI-C005" class="language_list_box"><a id="en-US" class="language_item" onclick="onSelectLanguage('en-US', '/auth/UI/Login?MajorVersion=1&ProviderID=https%3A%2F%2Femea1.proxy.cp.thomsonreuters.com%3A443%2Famagent&RequestID=5D7D1725D7E6ED3E537A3D3EA16029345EACC06FB3F940D77A4288EC0B6EC759&MinorVersion=0&theme=charcoal&IssueInstant=2023-07-04T19%3A05%3A03Z&product=refinitiv&goto=%2Fauth%2Fcdcservlet%3FTARGET%3Dhttps%253A%252F%252Femea1.apps.cp.thomsonreuters.com%252FApps%252FUDF%252FMSF%253Fampostpreserve%253D85720bd0-fc6b-3a45-90f5-8a980c73e20e%2526srv%253DDTCP-ERPCPRP08%26MajorVersion%3D1%26ProviderID%3Dhttps%253A%252F%252Femea1.proxy.cp.thomsonreuters.com%253A443%252Famagent%26RequestID%3D5D7D1725D7E6ED3E537A3D3EA16029345EACC06FB3F940D77A4288EC0B6EC759%26MinorVersion%3D0%26theme%3Dcharcoal%26IssueInstant%3D2023-07-04T19%253A05%253A03Z%26product%3Drefinitiv%26locale%3Den-US&locale=en-US' ,'AAA-AS-SI-C005', 'AAA-AS-SI-C004', 'AAA-AS-SI-SE020')" href="#" tabIndex='-1'> English </a><a id="ja-JP" class="language_item" onclick="onSelectLanguage('ja-JP', '/auth/UI/Login?MajorVersion=1&ProviderID=https%3A%2F%2Femea1.proxy.cp.thomsonreuters.com%3A443%2Famagent&RequestID=5D7D1725D7E6ED3E537A3D3EA16029345EACC06FB3F940D77A4288EC0B6EC759&MinorVersion=0&theme=charcoal&IssueInstant=2023-07-04T19%3A05%3A03Z&product=refinitiv&goto=%2Fauth%2Fcdcservlet%3FTARGET%3Dhttps%253A%252F%252Femea1.apps.cp.thomsonreuters.com%252FApps%252FUDF%252FMSF%253Fampostpreserve%253D85720bd0-fc6b-3a45-90f5-8a980c73e20e%2526srv%253DDTCP-ERPCPRP08%26MajorVersion%3D1%26ProviderID%3Dhttps%253A%252F%252Femea1.proxy.cp.thomsonreuters.com%253A443%252Famagent%26RequestID%3D5D7D1725D7E6ED3E537A3D3EA16029345EACC06FB3F940D77A4288EC0B6EC759%26MinorVersion%3D0%26theme%3Dcharcoal%26IssueInstant%3D2023-07-04T19%253A05%253A03Z%26product%3Drefinitiv%26locale%3Dja-JP&locale=ja-JP' ,'AAA-AS-SI-C005', 'AAA-AS-SI-C004', 'AAA-AS-SI-SE020')" href="#" tabIndex='-1'> 日本語 </a><a id="zh-CN" class="language_item" onclick="onSelectLanguage('zh-CN', '/auth/UI/Login?MajorVersion=1&ProviderID=https%3A%2F%2Femea1.proxy.cp.thomsonreuters.com%3A443%2Famagent&RequestID=5D7D1725D7E6ED3E537A3D3EA16029345EACC06FB3F940D77A4288EC0B6EC759&MinorVersion=0&theme=charcoal&IssueInstant=2023-07-04T19%3A05%3A03Z&product=refinitiv&goto=%2Fauth%2Fcdcservlet%3FTARGET%3Dhttps%253A%252F%252Femea1.apps.cp.thomsonreuters.com%252FApps%252FUDF%252FMSF%253Fampostpreserve%253D85720bd0-fc6b-3a45-90f5-8a980c73e20e%2526srv%253DDTCP-ERPCPRP08%26MajorVersion%3D1%26ProviderID%3Dhttps%253A%252F%252Femea1.proxy.cp.thomsonreuters.com%253A443%252Famagent%26RequestID%3D5D7D1725D7E6ED3E537A3D3EA16029345EACC06FB3F940D77A4288EC0B6EC759%26MinorVersion%3D0%26theme%3Dcharcoal%26IssueInstant%3D2023-07-04T19%253A05%253A03Z%26product%3Drefinitiv%26locale%3Dzh-CN&locale=zh-CN' ,'AAA-AS-SI-C005', 'AAA-AS-SI-C004', 'AAA-AS-SI-SE020')" href="#" tabIndex='-1'> 中文简体 </a></div><input class='hiddensubmit' type="hidden" id="AAA-AS-SI-C004" name="AAA-AS-SI-C004" value="en-US"/></div><script>function toggleArrow(dropdownId,toggleId){var el=document.getElementById(dropdownId);var toggleBox=document.getElementById(toggleId);if(el.style.display=="block"){toggleBox.classList.add("language-arrow-up")}else{toggleBox.classList.remove("language-arrow-up")}};</script></div></div></div><div class="body_main"><div class="signin_body_content"><div class="body_brand"><div id="AAA-AS-SI-SE006" class="product_brand_image"></div></div><div class="body_input"><form name="frmSignIn" action="blank" onSubmit="return defaultSubmitLoading('AAA-AS-SI1-SE014')" method="post"><table width='100%' cellspacing="1" cellpadding="0" border="0"><tr class='signin_input_row'><td width='76px'><label class='topic_txt' id="AAA-AS-SI1-SE002" for='IDToken1'> User ID: </label></td><td><div class="textbox_img textbox_img_big2"><input type="text" id="AAA-AS-SI1-SE003" name="IDToken1" placeholder="User ID" value="" autocomplete="off" tabIndex='1'/></div></td></tr><tr cl ...
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# /var/folders/cv/_19ylw5j4hsbq7ctdf273z3m0000gn/T/ipykernel_49667/4195826262.py in <module>
# ----> 1 headlines = ek.get_news_headlines('AAPL.O',1)
#       2 story_id = headlines.iat[0,2]
#       3 story_id
#
# ~/opt/anaconda3/lib/python3.9/site-packages/refinitiv/data/eikon/_news_request.py in get_news_headlines(query, count, repository, date_from, date_to, raw_output, debug)
#     152
#     153     response = json_requests.send_json_request(News_Headlines_UDF_endpoint, payload, debug=debug)
# --> 154     result = response.json()
#     155
#     156     if raw_output:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/httpx/_models.py in json(self, **kwargs)
#     741             if encoding is not None:
#     742                 return jsonlib.loads(self.content.decode(encoding), **kwargs)
# --> 743         return jsonlib.loads(self.text, **kwargs)
#     744
#     745     @property
#
# ~/opt/anaconda3/lib/python3.9/json/__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     344             parse_int is None and parse_float is None and
#     345             parse_constant is None and object_pairs_hook is None and not kw):
# --> 346         return _default_decoder.decode(s)
#     347     if cls is None:
#     348         cls = JSONDecoder
#
# ~/opt/anaconda3/lib/python3.9/json/decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# ~/opt/anaconda3/lib/python3.9/json/decoder.py in raw_decode(self, s, idx)
#     353             obj, end = self.scan_once(s, idx)
#     354         except StopIteration as err:
# --> 355             raise JSONDecodeError("Expecting value", s, err.value) from None
#     356         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %% [markdown]
# #### Get the News story for this Story ID

# %%
story = ek.get_news_story(story_id)
HTML(story)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/cv/_19ylw5j4hsbq7ctdf273z3m0000gn/T/ipykernel_49667/505939832.py in <module>
# ----> 1 story = ek.get_news_story(story_id)
#       2 HTML(story)
#
# NameError: name 'story_id' is not defined
