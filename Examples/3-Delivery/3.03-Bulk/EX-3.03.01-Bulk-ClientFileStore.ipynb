# %% [markdown]
# ----
# <img src="../../../files/refinitiv.png" width="20%" style="vertical-align: top;">
#
# # Data Library for Python
#
# ----

# %% [markdown]
# ## Delivery layer - Bulk - Client File Store
# This notebook demonstrates how to browse the Client File Store (CFS) of the Refinitiv Data Platform (RDP) using the Refintiv Data Library. The delivery.bulk.cfs module used in this example gives you an fine control on CFS operations. Unless you have a specific need, it is recommended to use the delivery.bulk.PackageManager instead. The Package manager provides you with a higher level API that manages for you the 3 types of activities generally invoved with bulk files (downloading files, populating databases, querying databases).

# %% [markdown]
# #### Learn more
#
# To learn more about the Refinitiv Data Library for Python please join the Refinitiv Developer Community. By [registering](https://developers.refinitiv.com/iam/register) and [logging](https://developers.refinitiv.com/content/devportal/en_us/initCookie.html) into the Refinitiv Developer Community portal you will have free access to a number of learning materials like
#  [Quick Start guides](https://developers.refinitiv.com/en/api-catalog/refinitiv-data-platform/refinitiv-data-library-for-python/quick-start),
#  [Tutorials](https://developers.refinitiv.com/en/api-catalog/refinitiv-data-platform/refinitiv-data-library-for-python/learning),
#  [Documentation](https://developers.refinitiv.com/en/api-catalog/refinitiv-data-platform/refinitiv-data-library-for-python/docs)
#  and much more.
#
# #### Getting Help and Support
#
# If you have any questions regarding using the API, please post them on
# the [Refinitiv Data Q&A Forum](https://community.developers.refinitiv.com/spaces/321/index.html).
# The Refinitiv Developer Community will be happy to help.

# %% [markdown]
# ## Set the configuration file location
# For a better ease of use, you have the option to set initialization parameters of the Refinitiv Data Library in the _refinitiv-data.config.json_ configuration file. This file must be located beside your notebook, in your user folder or in a folder defined by the _RD_LIB_CONFIG_PATH_ environment variable. The _RD_LIB_CONFIG_PATH_ environment variable is the option used by this series of examples. The following code sets this environment variable.

# %%
import os
os.environ["RD_LIB_CONFIG_PATH"] = "../../../Configuration"

# %% [markdown]
# ## Some Imports to start with

# %%
import refinitiv.data as rd
import refinitiv.data.delivery.cfs as cfs
from datetime import timedelta

# %% [markdown]
# ## Open the data session
#
# The open_session() function creates and open sessions based on the information contained in the refinitiv-data.config.json configuration file. Please edit this file to set the session type and other parameters required for the session you want to open.

# %%
rd.open_session('platform.rdp')
# Out:
# <refinitiv.data.session.Definition object at 0x7fa5d9a8e880 {name='rdp'}>

# %% [markdown]
# ## Retrieve data

# %% [markdown]
# ### Buckets

# %% [markdown]
# #### Get all buckets

# %%
response = cfs.buckets.Definition().get_data()
response.data.df
# Out:
# ---------------------------------------------------------------------------
# ScopeError                                Traceback (most recent call last)
# /var/folders/cv/_19ylw5j4hsbq7ctdf273z3m0000gn/T/ipykernel_49099/1250885990.py in <module>
# ----> 1 response = cfs.buckets.Definition().get_data()
#       2 response.data.df
#
# ~/opt/anaconda3/lib/python3.9/site-packages/refinitiv/data/delivery/_data/_data_provider_layer.py in get_data(self, session, on_response)
#     146         """
#     147         session = get_valid_session(session)
# --> 148         response = get_data(self._data_type, self._provider, session, **self._kwargs)
#     149         on_response and emit_event(on_response, response, self, session)
#     150         self._check_response(response, session.config)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/refinitiv/data/delivery/_data/_data_provider_layer.py in get_data(data_type, provider, session, **kwargs)
#      48         desc={FilterType.SYNC, FilterType.LAYER_DELIVERY},
#      49     )
# ---> 50     response = provider.get_data(session, url, auto_retry=auto_retry, **kwargs)
#      51     return response
#      52
#
# ~/opt/anaconda3/lib/python3.9/site-packages/refinitiv/data/delivery/_data/_data_provider.py in get_data(self, session, *args, **kwargs)
#      84         request = self.request.create(session, *args, **kwargs)
#      85         raw_response = self.connection.send(request, session, *args, **kwargs)
# ---> 86         return self._process_response(raw_response, request, session, *args, **kwargs)
#      87
#      88     async def get_data_async(self, session: "Session", *args, **kwargs) -> BaseResponse:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/refinitiv/data/delivery/_data/_data_provider.py in _process_response(self, raw_response, base_request, session, *args, **kwargs)
#      76     ) -> BaseResponse:
#      77         is_success, parsed_data = self.parser.parse_raw_response(raw_response)
# ---> 78         self._handle_scope_error(base_request, session, parsed_data)
#      79         is_success = is_success and self.validator.validate(parsed_data)
#      80         return self.response.create_response(is_success, parsed_data=parsed_data, session=session, **kwargs)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/refinitiv/data/delivery/_data/_data_provider.py in _handle_scope_error(self, request, session, parsed_data)
#      61     def _handle_scope_error(self, request: Request, session: "Session", parsed_data):
#      62         if 403 in parsed_data.error_codes:
# ---> 63             session._handle_insufficient_scope(
#      64                 request.path,
#      65                 request.method,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/refinitiv/data/_core/session/_platform_session.py in _handle_insufficient_scope(self, path, method, message)
#     264         required_scopes = [set(i.split()) for i in required_scope_groups]
#     265         self._connection.auth_manager.set_scope(path, method, required_scopes)
# --> 266         raise ScopeError(
#     267             required_scopes,
#     268             self._connection.auth_manager._token_info.scope,
#
# ScopeError: Error code -1 | Insufficient scope for key=/file-store/v1/buckets, method=GET.
# Required scopes: {'trapi.cfs.publisher.read'} OR {'trapi.cfs.subscriber.read'}
# Available scopes: {'trapi.search.explore.read', 'trapi.sdbold', 'trapi.frtb.sentimarization', 'trapi.graphql.subscriber.access', 'trapi.searchcore.lookup.read', 'trapi.synthetic.crud', 'trapi.data.quantitative-analytics.read', 'trapi.alerts.subscription.crud', 'trapi.user-framework.mobile.crud', 'trapi.user-framework.workspace.crud', 'trapi.alerts.preferences.crud', 'trapi.alerts.history.crud', 'trapi.data.average-volume-analytics.ava_read', 'trapi.data.historical-pricing.summaries.read', 'trapi.streaming.synthetic.read', 'trapi.searchcore.metadata.read', 'trapi.user-framework.application-metadata.raplib', 'trapi.searchcore.read', 'trapi.data.get.data.read', 'trapi.alerts.publication.crud', 'trapi.streaming.prcperf.read', 'trapi.streaming.pricing.read', 'trapi.search.lookup.read', 'trapi.search.metadata.read', 'trapi.auth.cloud-credentials', 'trapi.user-framework.recently-used.crud', 'trapi.data.historical-pricing.events.read', 'trapi.search.read'}
# Missing scopes: {'trapi.cfs.publisher.read'} OR {'trapi.cfs.subscriber.read'}

# %% [markdown]
# #### Get buckets by name

# %%
response = cfs.buckets.Definition('bulk-ESG').get_data()
response.data.df
# Out:
# No user scope for key=/file-store/v1/buckets, method=GET.
# ---------------------------------------------------------------------------
# ScopeError                                Traceback (most recent call last)
# /var/folders/cv/_19ylw5j4hsbq7ctdf273z3m0000gn/T/ipykernel_49099/136066723.py in <module>
# ----> 1 response = cfs.buckets.Definition('bulk-ESG').get_data()
#       2 response.data.df
#
# ~/opt/anaconda3/lib/python3.9/site-packages/refinitiv/data/delivery/_data/_data_provider_layer.py in get_data(self, session, on_response)
#     146         """
#     147         session = get_valid_session(session)
# --> 148         response = get_data(self._data_type, self._provider, session, **self._kwargs)
#     149         on_response and emit_event(on_response, response, self, session)
#     150         self._check_response(response, session.config)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/refinitiv/data/delivery/_data/_data_provider_layer.py in get_data(data_type, provider, session, **kwargs)
#      48         desc={FilterType.SYNC, FilterType.LAYER_DELIVERY},
#      49     )
# ---> 50     response = provider.get_data(session, url, auto_retry=auto_retry, **kwargs)
#      51     return response
#      52
#
# ~/opt/anaconda3/lib/python3.9/site-packages/refinitiv/data/delivery/_data/_data_provider.py in get_data(self, session, *args, **kwargs)
#      82     def get_data(self, session: "Session", *args, **kwargs) -> BaseResponse:
#      83         raise_if_closed(session)
# ---> 84         request = self.request.create(session, *args, **kwargs)
#      85         raw_response = self.connection.send(request, session, *args, **kwargs)
#      86         return self._process_response(raw_response, request, session, *args, **kwargs)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/refinitiv/data/delivery/_data/_request_factory.py in create(self, session, url, *args, **kwargs)
#      17         method = self.get_request_method(**kwargs)
#      18         path = self.get_url(session, url, *args, **kwargs)
# ---> 19         session.verify_scope(path, method)
#      20         url_root = session._get_rdp_url_root()
#      21
#
# ~/opt/anaconda3/lib/python3.9/site-packages/refinitiv/data/_core/session/_platform_session.py in verify_scope(self, key, method)
#     248     def verify_scope(self, key: str, method: str):
#     249         if self._enable_scope_verification:
# --> 250             self._connection.auth_manager.verify_scope(key, method)
#     251
#     252     def _handle_insufficient_scope(self, path: str, method: str, message: str) -> None:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/refinitiv/data/_core/session/auth_manager.py in verify_scope(self, key, method)
#     359         ):
#     360             self.warning(f"No user scope for key={key}, method={method}.")
# --> 361             raise ScopeError(required_scope_sets, self._token_info.scope, key, method)
#
# ScopeError: Error code -1 | Insufficient scope for key=/file-store/v1/buckets, method=GET.
# Required scopes: {'trapi.cfs.publisher.read'} OR {'trapi.cfs.subscriber.read'}
# Available scopes: {'trapi.search.explore.read', 'trapi.sdbold', 'trapi.frtb.sentimarization', 'trapi.graphql.subscriber.access', 'trapi.searchcore.lookup.read', 'trapi.synthetic.crud', 'trapi.data.quantitative-analytics.read', 'trapi.alerts.subscription.crud', 'trapi.user-framework.mobile.crud', 'trapi.user-framework.workspace.crud', 'trapi.alerts.preferences.crud', 'trapi.alerts.history.crud', 'trapi.data.average-volume-analytics.ava_read', 'trapi.data.historical-pricing.summaries.read', 'trapi.streaming.synthetic.read', 'trapi.searchcore.metadata.read', 'trapi.user-framework.application-metadata.raplib', 'trapi.searchcore.read', 'trapi.data.get.data.read', 'trapi.alerts.publication.crud', 'trapi.streaming.prcperf.read', 'trapi.streaming.pricing.read', 'trapi.search.lookup.read', 'trapi.search.metadata.read', 'trapi.auth.cloud-credentials', 'trapi.user-framework.recently-used.crud', 'trapi.data.historical-pricing.events.read', 'trapi.search.read'}
# Missing scopes: {'trapi.cfs.publisher.read'} OR {'trapi.cfs.subscriber.read'}

# %% [markdown]
# #### Iterate buckets

# %%
response = cfs.buckets.Definition('bulk-ESG').get_data()

for bucket in response.data.buckets:
    print(bucket)
    for fileset in bucket:
        print("\t", fileset)
        for file in fileset:
            print("\t\t", file)

# %% [markdown]
# ### FileSets

# %% [markdown]
# #### Get FileSets of a bucket

# %%
response = cfs.file_sets.Definition('bulk-ESG').get_data()
response.data.df
# Out:
#    bucketName                                         attributes  \
# 0    bulk-ESG   [{'name': 'ContentType', 'value': 'ESG Scores'}]
# 1    bulk-ESG   [{'name': 'ContentType', 'value': 'ESG EU BMR'}]
# 2    bulk-ESG  [{'name': 'ResultCount', 'value': '69943'}, {'...
# 3    bulk-ESG  [{'name': 'ContentType', 'value': 'Symbology I...
# 4    bulk-ESG  [{'name': 'ContentType', 'value': 'Symbology S...
# 5    bulk-ESG  [{'name': 'ContentType', 'value': 'ESG Raw Cur...
# 6    bulk-ESG  [{'name': 'ContentType', 'value': 'ESG Raw Cur...
# 7    bulk-ESG   [{'name': 'ContentType', 'value': 'ESG Scores'}]
# 8    bulk-ESG   [{'name': 'ContentType', 'value': 'ESG Scores'}]
# 9    bulk-ESG  [{'name': 'ContentType', 'value': 'Symbology I...
# 10   bulk-ESG  [{'name': 'ContentType', 'value': 'ESG Raw Wea...
# 11   bulk-ESG  [{'name': 'ContentType', 'value': 'ESG Raw Cur...
# 12   bulk-ESG  [{'name': 'ContentType', 'value': 'ESG Raw Cur...
# 13   bulk-ESG  [{'name': 'ContentType', 'value': 'ESG Raw Ful...
# 14   bulk-ESG   [{'name': 'ContentType', 'value': 'ESG Scores'}]
# 15   bulk-ESG  [{'name': 'ContentType', 'value': 'ESG Raw Ful...
# 16   bulk-ESG  [{'name': 'ContentType', 'value': 'Symbology C...
# 17   bulk-ESG  [{'name': 'ContentType', 'value': 'ESG Raw Wea...
# 18   bulk-ESG  [{'name': 'ContentType', 'value': 'ESG Raw Ful...
# 19   bulk-ESG   [{'name': 'ContentType', 'value': 'ESG Scores'}]
# 20   bulk-ESG  [{'name': 'ContentType', 'value': 'ESG Raw Cur...
# 21   bulk-ESG  [{'name': 'ContentType', 'value': 'ESG Raw Ful...
# 22   bulk-ESG   [{'name': 'ContentType', 'value': 'ESG Scores'}]
# 23   bulk-ESG   [{'name': 'ContentType', 'value': 'ESG Scores'}]
# 24   bulk-ESG  [{'name': 'ContentType', 'value': 'Symbology O...
#
#                                                  name             contentTo  \
# 0   Bulk-ESG-Global-Scores-Full-v1-Jsonl-Delta-202...  2022-12-11T16:25:00Z
# 1   Bulk-ESG-Global-EU-BMR-v1-Jsonl-Init-2022-12-0...  2022-12-04T15:55:00Z
# 2   Bulk-ESG-Global-Sources-Full-v1-Jsonl-Delta-20...  2022-12-04T16:45:00Z
# 3   Bulk-ESG-Global-Symbology-ISIN-v1-Jsonl-Init-2...  2022-12-04T10:25:00Z
# 4   Bulk-ESG-Global-Symbology-SEDOL-v1-Jsonl-Init-...  2022-11-20T10:25:00Z
# 5   Bulk-ESG-Global-Raw-Current-Limited-SchemeB-v1...  2022-12
# 1  2022-12-04T10:34:40Z         1  2022-12-04T10:34:40Z  2022-12-18T10:34:40Z
# 2  2022-12-04T10:34:42Z         1  2022-12-04T10:34:42Z  2023-01-04T10:34:42Z
# 3  2022-12-04T10:35:06Z         1  2022-12-04T10:35:06Z  2022-12-18T10:35:05Z
# 4  2022-12-04T10:36:12Z         1  2022-12-04T10:36:12Z  2022-12-18T10:36:12Z
# 5  2022-12-04T10:45:38Z         1  2022-12-04T10:45:38Z  2022-12-18T10:45:38Z
# 6  2022-12-04T10:46:16Z         1  2022-12-04T10:46:16Z  2022-12-18T10:46:16Z
# 7  2022-12-04T10:46:18Z         1  2022-12-04T10:46:18Z  2023-01-04T10:46:18Z
# 8  2022-12-04T10:46:41Z         1  2022-12-04T10:46:41Z  2022-12-18T10:46:41Z
# 9  2022-12-04T10:47:13Z         1  2022-12-04T10:47:13Z  2022-12-18T10:47:13Z
#
#   status
# 0  READY
# 1  READY
# 2  READY
# 3  READY
# 4  READY
# 5  READY
# 6  READY
# 7  READY
# 8  READY
# 9  READY

# %% [markdown]
# #### Get FileSets with pagination

# %%
page1_response = cfs.file_sets.Definition(
    bucket='bulk-ESG', 
    page_size=5
).get_data()
display(page1_response.data.df)

token = page1_response.data.raw["skip_token"]

page2_response = cfs.file_sets.Definition(
    bucket='bulk-ESG',
    page_size=5,
    skip_token=token,
).get_data()
display(page2_response.data.df)
# Out:
#   bucketName                                         attributes  \
# 0   bulk-ESG   [{'name': 'ContentType', 'value': 'ESG Scores'}]
# 1   bulk-ESG   [{'name': 'ContentType', 'value': 'ESG EU BMR'}]
# 2   bulk-ESG  [{'name': 'ResultCount', 'value': '69943'}, {'...
# 3   bulk-ESG  [{'name': 'ContentType', 'value': 'Symbology I...
# 4   bulk-ESG  [{'name': 'ContentType', 'value': 'Symbology S...
#
#                                                 name             contentTo  \
# 0  Bulk-ESG-Global-Scores-Full-v1-Jsonl-Delta-202...  2022-12-11T16:25:00Z
# 1  Bulk-ESG-Global-EU-BMR-v1-Jsonl-Init-2022-12-0...  2022-12-04T15:55:00Z
# 2  Bulk-ESG-Global-Sources-Full-v1-Jsonl-Delta-20...  2022-12-04T16:45:00Z
# 3  Bulk-ESG-Global-Symbology-ISIN-v1-Jsonl-Init-2...  2022-12-04T10:25:00Z
# 4  Bulk-ESG-Global-Symbology-SEDOL-v1-Jsonl-Init-...  2022-11-20T10:25:00Z
#
#                                      id  \
# 0  4010-5730-b53a7546-ad9a-0ae591a4fed1
# 1  405e-257f-8f555107-90ea-04a4dadeaa86
# 2  405e-a8f2-4e0bfcc3-9014-4218f081a539
# 3  408f-0df2-ee2e4fda-a333-ea55c1d19a6a
# 4  40b0-5165-ec200230-84f9-09d527c460c2
#
#                                     files           contentFrom  \
# 0  [422b-b545-a0431e70-b15c-8d0fad346456]  2022-12-04T16:25:00Z
# 1  [4bf4-9a6a-69aec78b-b22d-a2631977a6c9]  1970-01-01T00:00:00Z
# 2  [4a48-2280-a32705a0-9e27-34d343d4afad]  2022-11-27T16:45:00Z
# 3  [4508-4e1f-d52415e1-be65-f1d323d21b59]  1970-01-01T00:00:00Z
# 4  [43df-4283-914e75ba-bf62-9ff0b391944f]  1970-01-01T00:00:00Z
#
#                modified                             packageId  \
# 0  2022-12-11T16:35:16Z  4f1d-c1e4-b448e23b-a51a-e4315800de31
# 1  2022-12-04T16:05:12Z  48d4-e278-215dca78-bb4a-bca14a86a8f5
# 2  2022-12-04T16:54:46Z  43ac-6749-947dd136-bad9-f4d575af2253
# 3  2022-12-04T10:34:45Z  444f-4895-36da1f18-9930-c3d6a89fac7c
# 4  2022-11-20T10:47:44Z  48ff-7e86-20bd08b2-8bbf-ee1b93395d59
#
#           availableFrom  numFiles               created           availableTo  \
# 0  2022-12-11T16:34:42Z         1  2022-12-11T16:34:42Z  2022-12-25T16:34:42Z
# 1  2022-12-04T16:04:17Z         1  2022-12-04T16:04:17Z  2022-12-18T16:04:17Z
# 2  2022-12-04T16:54:20Z         1  2022-12-04T16:54:20Z  2022-12-18T16:54:19Z
# 3  2022-12-04T10:34:42Z         1  2022-12-04T10:34:42Z  2023-01-04T10:34:42Z
# 4  2022-11-20T10:47:35Z         1  2022-11-20T10:47:35Z  2022-12-20T10:47:35Z
#
#   status
# 0  READY
# 1  READY
# 2  READY
# 3  READY
# 4  READY
#   bucketName                                         attributes  \
# 0   bulk-ESG  [{'name': 'ContentType', 'value': 'ESG Raw Cur...
# 1   bulk-ESG  [{'name': 'ContentType', 'value': 'ESG Raw Cur...
# 2   bulk-ESG   [{'name': 'ContentType', 'value': 'ESG Scores'}]
# 3   bulk-ESG   [{'name': 'ContentType', 'value': 'ESG Scores'}]
# 4   bulk-ESG  [{'name': 'ContentType', 'value': 'Symbology I...
#
#                                                 name             contentTo  \
# 0  Bulk-ESG-Global-Raw-Current-Limited-SchemeB-v1...  2022-12-11T17:35:00Z
# 1  Bulk-ESG-Global-Raw-Current-Limited-SchemeB-v1...  2022-12-04T17:35:00Z
# 2  Bulk-ESG-Global-Scores-Wealth-Standard-v1-Json...  2022-12-04T17:15:00Z
# 3  Bulk-ESG-Global-Scores-Full-v1-Jsonl-Delta-202...  2022-12-04T16:25:00Z
# 4  Bulk-ESG-Global-Symbology-InstrumentQuote-v1-J...  2022-12-04T10:25:00Z
#
#                                      id  \
# 0  40e8-8013-8efa3636-8820-1a94fe627291
# 1  40f7-9cd9-ff2e3c7d-819d-6e082ec8071e
# 2  4116-3460-006487a2-b7ce-6a8f2d659335
# 3  412d-82bd-e5a10723-834a-1e9298e5e22e
# 4  414d-b6a5-d2cf1498-9b8a-dc657ee67e22
#
#                                     files           contentFrom  \
# 0  [495a-b597-10aa1b9f-a7d1-73f8f9ce6b46]  2022-12-04T17:35:00Z
# 1  [4ca6-efb9-a46da6da-994c-ed11da669e2e]  2022-11-27T17:35:00Z
# 2  [483e-a433-194323d0-9d51-e21c9011dae1]  1970-01-01T00:00:00Z
# 3  [42af-2bd7-5d915c41-8802-871fbda73d07]  2022-11-27T16:25:00Z
# 4  [4ad2-d94b-944646e5-8001-3b22af8386a7]  1970-01-01T00:00:00Z
#
#                modified                             packageId  \
# 0  2022-12-11T17:42:36Z  448b-4cc8-301b4e6a-9f6e-a0935eb8454b
# 1  2022-12-04T17:42:29Z  448b-4cc8-301b4e6a-9f6e-a0935eb8454b
# 2  2022-12-04T17:24:42Z  4d07-921a-7337a7cc-a291-e5b049ddf4dc
# 3  2022-12-04T16:35:10Z  4f1d-c1e4-b448e23b-a51a-e4315800de31
# 4  2022-12-04T10:49:12Z  4dc5-4efa-bf8327db-8997-57899e9833cc
#
#           availableFrom  numFiles               created           availableTo  \
# 0  2022-12-11T17:42:24Z         1  2022-12-11T17:42:24Z  2022-12-25T17:42:24Z
# 1  2022-12-04T17:42:14Z         1  2022-12-04T17:42:14Z  2022-12-18T17:42:14Z
# 2  2022-12-04T17:24:17Z         1  2022-12-04T17:24:17Z  2022-12-18T17:24:17Z
# 3  2022-12-04T16:34:35Z         1  2022-12-04T16:34:35Z  2022-12-18T16:34:35Z
# 4  2022-12-04T10:48:04Z         1  2022-12-04T10:48:04Z  2022-12-18T10:48:04Z
#
#   status
# 0  READY
# 1  READY
# 2  READY
# 3  READY
# 4  READY

# %% [markdown]
# ### Files

# %% [markdown]
# #### Get Files of a FileSet

# %%
first_file_set_id = page1_response.data.df.at[0,'id']

response = cfs.files.Definition(first_file_set_id).get_data()
response.data.df
# Out:
#    fileSizeInBytes                               md5  \
# 0         13640237  a5d506992be6131d4adc1cbe49fe64e6
#
#                                      id                             filesetId  \
# 0  422b-b545-a0431e70-b15c-8d0fad346456  4010-5730-b53a7546-ad9a-0ae591a4fed1
#
#                modified                                           filename  \
# 0  2022-12-11T16:34:51Z  Bulk-ESG-Global-Scores-Full-v1-Delta-2022-12-1...
#
#                                                 href               created  \
# 0  https://api.refinitiv.com/file-store/v1/files/...  2022-12-11T16:34:51Z
#
#                                      storageLocation
# 0  {'url': 'https://a206464-bulk-esg.s3.amazonaws...

# %% [markdown]
# ### FileDownloader

# %%
first_file = response.data.files[0]
file_downloader = cfs.file_downloader.Definition(first_file).retrieve()
file_downloader.download()
file_downloader.extract()
# Out:
# 'Bulk-ESG-Global-Scores-Full-v1-Delta-2022-12-11T163135.260Z.jsonl'

# %% [markdown]
# ### Packages

# %% [markdown]
# #### Get Packages

# %%
response = cfs.packages.Definition('RFT-ESG-Scores-Wealth-Standard').get_data()
response.data.df
# Out:
#                 contactEmail     bucketNames packageType  \
# 0  anita.varma@refinitiv.com  [rft-bulk-esg]        bulk
# 1       anita.varma@lseg.com           [ESG]        bulk
#
#                 created              modified  \
# 0  2021-07-12T06:45:37Z  2021-07-12T06:45:37Z
# 1  2020-10-09T13:55:14Z  2022-10-21T09:56:43Z
#
#                          packageName                             packageId
# 0  RFT-ESG-Scores-Wealth-Standard-v1  411f-f1a0-b6869167-a819-30c04e554fc6
# 1     RFT-ESG-Scores-Wealth-Standard  4bcc-4602-0a57ebb2-baf0-1fc9825e76b6

# %% [markdown]
# #### Get Packages with more filters

# %%
response = cfs.packages.Definition(
    package_name="VBD",
    package_type="core",
    bucket_name="TICKHISTORY_VBD_LIMITED",
    page=10,
    page_size=10,
).get_data()
response.data.df
# Out:
#                modified                      packageName  \
# 0  2020-11-23T06:01:11Z                   VBD_MEX_SYM_5Y
# 1  2020-11-23T04:15:58Z   VBD_BRU_REF_DATA_CUSIP_GICS_5Y
# 2  2021-11-01T09:55:48Z                VBD_CHE_RAW_MP_5Y
# 3  2021-12-05T04:10:03Z        VBD_PTX_NORMALISED_MBO_5Y
# 4  2020-11-23T06:51:39Z  VBD_DMX_SYM_CUSIP_SEDOL_GICS_5Y
# 5  2020-11-23T06:36:03Z        VBD_SCZ_REF_INIT_SEDOL_5Y
# 6  2020-11-23T06:53:20Z              VBD_TBE_SYM_GICS_5Y
# 7  2020-11-23T05:15:54Z   VBD_TWA_TREU_SYM_SEDOL_GICS_5Y
# 8  2020-11-23T05:17:33Z  VBD_BCU_REF_INIT_CUSIP_SEDOL_5Y
# 9  2020-11-23T07:14:10Z   VBD_TAI_REF_DATA_CUSIP_GICS_5Y
#
#                               packageId          contactEmail packageType  \
# 0  4020-6002-8a707342-be53-88aa6c7e0537  kraken@refinitiv.com        core
# 1  4020-ccb5-5e51d1af-bd94-bc99948046d2  kraken@refinitiv.com        core
# 2  4020-df87-9c64817a-9c67-efddebffbf4d  kraken@refinitiv.com        core
# 3  4021-71c8-0b7bb5f8-9d8a-37b8e6be645f  kraken@refinitiv.com        core
# 4  4021-791d-6acc1987-9802-1ac35bf99d10  kraken@refinitiv.com        core
# 5  4022-4ea0-7a90068e-a137-5b833c9d87d3  kraken@refinitiv.com        core
# 6  4022-99ba-13b70471-acf4-a75383927f01  kraken@refinitiv.com        core
# 7  4022-f047-35cea0f8-9254-f14f034959bf  kraken@refinitiv.com        core
# 8  4023-67b0-e62e5d64-a88f-1db47a9f8a85  kraken@refinitiv.com        core
# 9  4024-2b55-8e247668-b1db-1e6994e2d0bd  kraken@refinitiv.com        core
#
#                  bucketNames  \
# 0  [TICKHISTORY_VBD_LIMITED]
# 1  [TICKHISTORY_VBD_LIMITED]
# 2  [TICKHISTORY_VBD_LIMITED]
# 3  [TICKHISTORY_VBD_LIMITED]
# 4  [TICKHISTORY_VBD_LIMITED]
# 5  [TICKHISTORY_VBD_LIMITED]
# 6  [TICKHISTORY_VBD_LIMITED]
# 7  [TICKHISTORY_VBD_LIMITED]
# 8  [TICKHISTORY_VBD_LIMITED]
# 9  [TICKHISTORY_VBD_LIMITED]
#
#                                          description               created
# 0  Package for venue MEX with view sym and depth ...  2020-08-29T16:16:54Z
# 1  Package for venue BRU with view ref-data-cusip...  2020-08-29T15:08:24Z
# 2  Package for venue CHE with view rawMP and dept...  2020-08-29T15:49:47Z
# 3  Package for venue PTX with view normalisedMBO ...  2021-12-05T04:10:03Z
# 4  Package for venue DMX with view sym-cusip-sedo...  2020-08-29T16:52:56Z
# 5  Package for venue SCZ with view ref-init-sedol...  2020-08-29T16:42:08Z
# 6  Package for venue TBE with view sym-gics and d...  2020-08-29T16:54:04Z
# 7  Package for venue TWA_TREU with view sym-sedol...  2020-08-29T15:47:22Z
# 8  Package for venue BCU with view ref-init-cusip...  2020-08-29T15:48:26Z
# 9  Package for venue TAI with view ref-data-cusip...  2020-08-29T17:07:56Z

# %% [markdown]
# ## Close the session

# %%
rd.close_session()
